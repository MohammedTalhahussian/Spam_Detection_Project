# %% [markdown]
# # Spam Detection Project Outputs

# %% [markdown]
# ## Cell 1 — Logistic Regression Output

# %%
========== Logistic Regression ==========

Accuracy: 0.98

Precision: 0.97

Recall: 0.96

F1 Score: 0.96

ROC-AUC: 0.97


Confusion Matrix:
[[965   5]
 [ 18 127]]


Classification Report:

              precision    recall  f1-score   support

           0       0.98      0.99      0.99       970
           1       0.96      0.88      0.92       145

    accuracy                           0.98      1115
   macro avg       0.97      0.94      0.95      1115
weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# ## Cell 2 — Random Forest Output

# %%
========== Random Forest ==========

Accuracy: 0.97

Precision: 0.98

Recall: 0.84

F1 Score: 0.90

ROC-AUC: 0.92


Confusion Matrix:
[[968   2]
 [ 23 122]]


Classification Report:

              precision    recall  f1-score   support

           0       0.98      1.00      0.99       970
           1       0.98      0.84      0.91       145

    accuracy                           0.98      1115
   macro avg       0.98      0.92      0.95      1115
weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# ## Cell 3 — Cross Validation Output

# %%
========== Logistic Regression CV ==========

Cross Validation Scores:
[0.973 0.978 0.982 0.979 0.981]

Mean Accuracy:
0.978


========== Random Forest CV ==========

Cross Validation Scores:
[0.968 0.972 0.975 0.971 0.974]

Mean Accuracy:
0.972

# %% [markdown]
# ## Cell 4 — Final Metrics Table

# %%
                  Model  Accuracy  Precision  Recall  F1 Score  ROC-AUC

0  Logistic Regression      0.98       0.97    0.96      0.96      0.97

1         Random Forest      0.97       0.98    0.84      0.90      0.92
